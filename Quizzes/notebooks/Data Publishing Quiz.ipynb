# %% [markdown]
# # Data processing and quality control Quiz
# ----
# ### (11 Questions)

# %%
from quiz import Quiz, load_style
load_style()

# %%
q = Quiz('publishing_quiz.json')

# %%
q.display_questions()
